# %%
## cargar data set y filtar por uso de aire /no
import pandas as pd
datos = pd.read_csv('../Dataset/household_energy_consumption.csv')

#filtar datos por uso de aire acondicionado
datos_aire = datos[datos['Has_AC'] == 'Yes']
datos_aire.to_csv('../Dataset/datos_aire.csv', index=False)

#filtrar datos por no uso de aire acondicionado
datos_no_aire = datos[datos['Has_AC'] == 'No']
datos_no_aire.to_csv('../Dataset/datos_no_aire.csv', index=False)
# Out:
#       Household_ID        Date  Energy_Consumption_kWh  Household_Size  \
# 21          H00004  2025-04-01                    18.8               5
# 22          H00004  2025-04-02                    18.8               5
# 23          H00004  2025-04-03                    20.0               5
# 24          H00004  2025-04-04                    16.1               5
# 25          H00004  2025-04-05                    17.4               5
# ...            ...         ...                     ...             ...
# 89980       H12855  2025-04-03                     8.3               2
# 89981       H12855  2025-04-04                     7.1               2
# 89982       H12855  2025-04-05                     8.5               2
# 89983       H12855  2025-04-06                     5.8               2
# 89984       H12855  2025-04-07                     6.6               2
#
#        Avg_Temperature_C Has_AC  Peak_Hours_Usage_kWh
# 21                  16.8    Yes                   7.8
# 22                  16.2    Yes                   9.2
# 23                  20.2    Yes                   8.7
# 24                  16.4    Yes                   7.4
# 25                  14.0    Yes                   7.2
# ...                  ...    ...                   ...
# 89980               22.6    Yes                   3.6
# 89981               16.9    Yes                   3.2
# 89982               17.0    Yes                   3.6
# 89983               16.4    Yes                   2.7
# 89984               16.2    Yes                   3.1
#
# [44492 rows x 7 columns]
